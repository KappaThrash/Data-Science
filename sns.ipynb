# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
sns.set_theme()
sns.set_style('whitegrid')

data = sns.load_dataset('tips')
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x= 'tip', y= 'total_bill', data=data, hue='day',size='size',style='sex')
plt.tight_layout
plt.xlabel('Gorjeta')
plt.ylabel('Pagamento')
plt.title('Relação entre Pagamento e Gorjeta')
plt.grid()
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# %%
sns.countplot(x='sex', hue='smoker', data=data)
plt.tight_layout
plt.title('Quantidade de fumantes em relação ao sexo')
plt.xlabel('Sexo')
plt.ylabel('Contagem')
# Out:
# Text(0, 0.5, 'Contagem')

# %%
sns.countplot(x='time' ,data=data)
plt.title('Quantidade de clientes em cada dado horario')
plt.xlabel('Horario')
plt.ylabel('Quantidade')
# Out:
# Text(0, 0.5, 'Quantidade')

# %%
sns.kdeplot(x='total_bill', y='tip', data=data, fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
